# %% [markdown]
# # FHIR SQL Builder

# %% [markdown]
# ## Retrieve FHIR resources via SQL statements

# %%
import cartopy.crs as ccrs
import matplotlib.pyplot as plt

ax = plt.axes(projection=ccrs.PlateCarree())
ax.coastlines()
plt.show()
# Out:
# /opt/conda/lib/python3.11/site-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/110m_physical/ne_110m_coastline.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)

# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pyplot as plt
import numpy as np

# Créer des données fictives
lons = np.linspace(-180, 180, 360)
lats = np.linspace(-90, 90, 180)
data = np.random.rand(180, 360)

# Créer une figure et un axe avec la projection souhaitée
fig = plt.figure(figsize=(10, 8))
ax = plt.axes(projection=ccrs.PlateCarree())

# Tracer les contours remplis des données
cs = ax.contourf(lons, lats, data, 30, transform=ccrs.PlateCarree())

# Ajouter les côtes
ax.coastlines()

# Ajouter les frontières des pays
ax.add_feature(cfeature.BORDERS)

# Ajouter une barre de couleurs
fig.colorbar(cs, shrink=0.75)

# Définir les limites de la carte
ax.set_extent([-100, -50, 20, 50], ccrs.PlateCarree())

# Ajouter une grille
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=1, color='gray', alpha=0.5, linestyle='--')
gl.xlabels_top = False
gl.ylabels_right = False

plt.show()
# Out:
# /opt/conda/lib/python3.11/site-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/50m_physical/ne_50m_coastline.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)
# /opt/conda/lib/python3.11/site-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/50m_cultural/ne_50m_admin_0_boundary_lines_land.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)

# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pyplot as plt
import numpy as np

# Créer des données fictives pour les lead times par pays
lead_times = {
    'France': 10,
    'Allemagne': 8,
    'Italie': 12,
    'Espagne': 9,
    'Royaume-Uni': 11
    # Ajouter d'autres pays ici
}

# Créer une figure et un axe avec la projection souhaitée
fig = plt.figure(figsize=(10, 8))
ax = plt.axes(projection=ccrs.PlateCarree())

# Ajouter les côtes et les frontières des pays
ax.coastlines()
ax.add_feature(cfeature.BORDERS)

# Ajouter des bulles pour les lead times par pays
for country, lead_time in lead_times.items():
    # Générer des coordonnées aléatoires pour le pays
    lon = np.random.uniform(-10, 10)
    lat = np.random.uniform(40, 60)
    # Ajouter une bulle à la carte
    ax.plot(lon, lat, 'o', markersize=lead_time, transform=ccrs.PlateCarree())

# Définir les limites de la carte
ax.set_extent([-20, 30, 30, 70], ccrs.PlateCarree())

# Ajouter une grille
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=1, color='gray', alpha=0.5, linestyle='--')
gl.xlabels_top = False
gl.ylabels_right = False

plt.show()

# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pyplot as plt
import numpy as np

# Données fictives sur les lead times par pays
lead_times = {
    'France': 10, 'Allemagne': 8, 'Italie': 12, 'Espagne': 9, 'Royaume-Uni': 11,
    'Russie': 15, 'Turquie': 14, 'Pologne': 7, 'Pays-Bas': 6, 'Belgique': 5
}

# Coordonnées des capitales des pays
capitals = {
    'France': (2.3522, 48.8566), 'Allemagne': (13.4050, 52.5200), 'Italie': (12.4964, 41.9028), 
    'Espagne': (-3.7038, 40.4168), 'Royaume-Uni': (-0.1278, 51.5074), 'Russie': (37.6173, 55.7558),
    'Turquie': (28.9784, 41.0086), 'Pologne': (21.0122, 52.2297), 'Pays-Bas': (4.8945, 52.3738),
    'Belgique': (4.3517, 50.8503)
}

# Créer une figure et un axe avec la projection souhaitée
fig = plt.figure(figsize=(10, 8))
ax = plt.axes(projection=ccrs.PlateCarree())

# Ajouter les côtes et les frontières des pays
ax.coastlines()
ax.add_feature(cfeature.BORDERS)

# Ajouter les bulles pour les lead times par pays
for country, lead_time in lead_times.items():
    lon, lat = capitals[country]
    ax.plot(lon, lat, 'ro', markersize=lead_time*2, transform=ccrs.PlateCarree())

# Définir les limites

# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pyplot as plt
import numpy as np

# Données fictives sur les lead times par pays
lead_times = {
    'France': 10, 'Allemagne': 8, 'Italie': 12, 'Espagne': 9, 'Royaume-Uni': 11,
    'Russie': 15, 'Turquie': 14, 'Pologne': 7, 'Pays-Bas': 6, 'Belgique': 5
}

# Coordonnées des capitales des pays
capitals = {
    'France': (2.3522, 48.8566), 'Allemagne': (13.4050, 52.5200), 'Italie': (12.4964, 41.9028), 
    'Espagne': (-3.7038, 40.4168), 'Royaume-Uni': (-0.1278, 51.5074), 'Russie': (37.6173, 55.7558),
    'Turquie': (28.9784, 41.0086), 'Pologne': (21.0122, 52.2297), 'Pays-Bas': (4.8945, 52.3738),
    'Belgique': (4.3517, 50.8503)
}

# Créer une figure et un axe avec la projection souhaitée
fig = plt.figure(figsize=(10, 8))
ax = plt.axes(projection=ccrs.PlateCarree())

# Ajouter les côtes et les frontières des pays
ax.coastlines()
ax.add_feature(cfeature.BORDERS)

# Ajouter les bulles pour les lead times par pays
for country, lead_time in lead_times.items():
    lon, lat = capitals[country]
    if lead_time <= 8:
        color = 'green'
    elif lead_time <= 12:
        color = 'orange'
    else:
        color = 'red'
    ax.plot(lon, lat, 'o', markersize=lead_time*2, color=color, transform=ccrs.PlateCarree())
    ax.text(lon, lat, str(lead_time), ha='center', va='bottom', transform=ccrs.PlateCarree())

# Définir les limites de la carte
ax.set_extent([-10, 45, 35, 65], ccrs.PlateCarree())

# Ajouter une grille
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=1, color='gray', alpha=0.5, linestyle='--')
gl.xlabels_top = False
gl.ylabels_right = False

plt.show()

# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pyplot as plt
import numpy as np

# Données fictives sur les lead times par pays
lead_times = {
    'France': 10, 'Allemagne': 8, 'Italie': 12, 'Espagne': 9, 'Royaume-Uni': 11,
    'Russie': 15, 'Turquie': 14, 'Pologne': 7, 'Pays-Bas': 6, 'Belgique': 5
}

# Coordonnées des capitales des pays
capitals = {
    'France': (2.3522, 48.8566), 'Allemagne': (13.4050, 52.5200), 'Italie': (12.4964, 41.9028), 
    'Espagne': (-3.7038, 40.4168), 'Royaume-Uni': (-0.1278, 51.5074), 'Russie': (37.6173, 55.7558),
    'Turquie': (28.9784, 41.0086), 'Pologne': (21.0122, 52.2297), 'Pays-Bas': (4.8945, 52.3738),
    'Belgique': (4.3517, 50.8503)
}

# Créer une figure et un axe avec la projection souhaitée
fig = plt.figure(figsize=(10, 8))
ax = plt.axes(projection=ccrs.PlateCarree())

# Ajouter le fond de carte
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS, linestyle=':')

# Ajouter les bulles pour les lead times par pays
for country, lead_time in lead_times.items():
    lon, lat = capitals[country]
    if lead_time <= 8:
        color = 'green'
    elif lead_time <= 12:
        color = 'orange'
    else:
        color = 'red'
    ax.plot(lon, lat, 'o', markersize=lead_time*2, color=color, transform=ccrs.PlateCarree())
    ax.text(lon, lat, str(lead_time), ha='center', va='bottom', transform=ccrs.PlateCarree())

# Définir les limites de la carte
ax.set_extent([-10, 45, 35, 65], ccrs.PlateCarree())

# Ajouter une grille
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=1, color='gray', alpha=0.5, linestyle='--')
gl.xlabels_top = False
gl.ylabels_right = False

plt.show()
# Out:
# /opt/conda/lib/python3.11/site-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/50m_physical/ne_50m_land.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)
# /opt/conda/lib/python3.11/site-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/50m_physical/ne_50m_ocean.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)

# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pyplot as plt
import numpy as np

# Données fictives sur les lead times par pays
lead_times = {
    'France': 100, 'Allemagne': 8, 'Italie': 12, 'Espagne': 9, 'Royaume-Uni': 11,
    'Russie': 15, 'Turquie': 14, 'Pologne': 7, 'Pays-Bas': 6, 'Belgique': 5
}

# Coordonnées des capitales des pays
capitals = {
    'France': (2.3522, 48.8566), 'Allemagne': (13.4050, 52.5200), 'Italie': (12.4964, 41.9028), 
    'Espagne': (-3.7038, 40.4168), 'Royaume-Uni': (-0.1278, 51.5074), 'Russie': (37.6173, 55.7558),
    'Turquie': (28.9784, 41.0086), 'Pologne': (21.0122, 52.2297), 'Pays-Bas': (4.8945, 52.3738),
    'Belgique': (4.3517, 50.8503)
}

# Créer une figure et un axe avec la projection souhaitée
fig = plt.figure(figsize=(10, 8))
ax = plt.axes(projection=ccrs.PlateCarree())

# Ajouter le fond de carte
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS, linestyle=':')

# Ajouter les bulles pour les lead times par pays
for country, lead_time in lead_times.items():
    lon, lat = capitals[country]
    if lead_time <= 8:
        color = 'green'
    elif lead_time <= 12:
        color = 'orange'
    else:
        color = 'red'
    ax.plot(lon, lat, 'o', markersize=lead_time*2, color=color, transform=ccrs.PlateCarree())
    ax.text(lon, lat, str(lead_time), ha='center', va='bottom', transform=ccrs.PlateCarree())

# Définir les limites de la carte
ax.set_extent([-10, 45, 35, 65], ccrs.PlateCarree())

# Ajouter une grille
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=1, color='gray', alpha=0.5, linestyle='--')
gl.xlabels_top = False
gl.ylabels_right = False

plt.show()

# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pyplot as plt
import numpy as np

# Données fictives sur les lead times par pays
lead_times = {
    'France': 35, 'Allemagne': 18, 'Italie': 12, 'Espagne': 9, 'Royaume-Uni': 11,
    'Russie': 15, 'Turquie': 14, 'Pologne': 7, 'Pays-Bas': 6, 'Belgique': 5
}

# Coordonnées des capitales des pays
capitals = {
    'France': (2.3522, 48.8566), 'Allemagne': (13.4050, 52.5200), 'Italie': (12.4964, 41.9028), 
    'Espagne': (-3.7038, 40.4168), 'Royaume-Uni': (-0.1278, 51.5074), 'Russie': (37.6173, 55.7558),
    'Turquie': (28.9784, 41.0086), 'Pologne': (21.0122, 52.2297), 'Pays-Bas': (4.8945, 52.3738),
    'Belgique': (4.3517, 50.8503)
}

# Créer une figure et un axe avec la projection souhaitée
fig = plt.figure(figsize=(10, 8))
ax = plt.axes(projection=ccrs.PlateCarree())

# Ajouter le fond de carte
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS, linestyle=':')

# Ajouter les bulles pour les lead times par pays
for country, lead_time in lead_times.items():
    lon, lat = capitals[country]
    if lead_time <= 8:
        color = 'green'
    elif lead_time <= 12:
        color = 'orange'
    else:
        color = 'red'
    ax.plot(lon, lat, 'o', markersize=lead_time*2, color=color, transform=ccrs.PlateCarree())
    ax.text(lon, lat, str(lead_time), ha='center', va='bottom', transform=ccrs.PlateCarree())

# Définir les limites de la carte
ax.set_extent([-10, 45, 35, 65], ccrs.PlateCarree())

# Ajouter une grille
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=1, color='gray', alpha=0.5, linestyle='--')
gl.xlabels_top = False
gl.ylabels_right = False

plt.show()

# %%
from datetime import date
import holidays

fr_holidays = holidays.FR()  

if date.today() in fr_holidays:
    print('today is public holiday')
else:
    print('working day')

check='2024-08-15'
if check in fr_holidays:
    print(check+' is public holiday')
else:
    print(check+'working day')
# Out:
# working day
# 2024-08-15 is public holiday

# %%
date.today() in fr_holidays
# Out:
# False

# %%
import pandas as pd
import intersystems_iris as iris
from sqlalchemy import create_engine,types

# %% [markdown]
# ## Create the SQL Alchemy engine

# %%
engine = create_engine('iris://SuperUser:SYS@iris:1972/IRISAPP')
engine
# Out:
# Engine(iris://SuperUser:***@iris:1972/IRISAPP)

# %% [markdown]
# ## Create the dbapi connection

# %%
host = "iris"
port = 1972
namespace = "IRISAPP"
user = "_SYSTEM"
password = "SYS"

conn = iris.connect(
                    hostname=host, 
                    port=port, 
                    namespace=namespace, 
                    username=user, 
                    password=password
                   )

# create a cursor
cur = conn.cursor()
conn

# %% [markdown]
# ## Display data from AA.Patient table after having created the FHIR SQL Builder projection

# %% [markdown]
# ### Alternatively, you can import the misc/T1.json transformation file using FHIR SQL Builder

# %%
pd.read_sql_table('Patient', engine, schema="AAA")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 pd.read_sql_table('Patient', engine, schema="AAA")
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/sql.py:386, in read_sql_table(table_name, con, schema, index_col, coerce_float, parse_dates, columns, chunksize, dtype_backend)
#     384 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
#     385     if not pandas_sql.has_table(table_name):
# --> 386         raise ValueError(f"Table {table_name} not found")
#     388     table = pandas_sql.read_table(
#     389         table_name,
#     390         index_col=index_col,
#    (...)
#     395         dtype_backend=dtype_backend,
#     396     )
#     398 if table is not None:
#
# ValueError: Table Patient not found

# %% [markdown]
# ## Create a dataframe from Location.csv file

# %%
df = pd.read_csv("Location.csv")
df.head()
# Out:
#        City     County  Latitude  Longitude State   0-4   5-9  10-14  15-19  \
# 0  Abington   Plymouth   42.1047   -70.9458    MA  0.04  0.05   0.05   0.07
# 1     Acton  Middlesex   42.4850   -71.4333    MA  0.06  0.05   0.07   0.11
# 2  Acushnet    Bristol   41.6806   -70.9083    MA  0.06  0.05   0.04   0.04
# 3     Adams  Berkshire   42.6242   -73.1181    MA  0.04  0.04   0.05   0.04
# 4    Agawam    Hampden   42.0696   -72.6152    MA  0.06  0.04   0.06   0.05
#
#    20-29  30-39  40-49  50-59  60-69  70-79   80+     F     M
# 0   0.13   0.14   0.14   0.16   0.12   0.07  0.03  0.51  0.49
# 1   0.07   0.09   0.16   0.19   0.10   0.07  0.03  0.52  0.48
# 2   0.12   0.11   0.13   0.18   0.13   0.11  0.03  0.52  0.48
# 3   0.16   0.12   0.12   0.15   0.16   0.07  0.05  0.48  0.52
# 4   0.10   0.10   0.13   0.17   0.14   0.09  0.06  0.51  0.49

# %% [markdown]
# ## Store Location dataframe into IRIS AB.Location table

# %%
df.to_sql('Location', engine, schema="AB" ,if_exists='replace', index=True)
# Out:
# -1

# %% [markdown]
# ## Read AB.Location table from IRIS

# %%
pd.read_sql_table('Location', engine, schema="AB")
# Out:
#      index         City      County  Latitude  Longitude State   0-4   5-9  \
# 0        0     Abington    Plymouth   42.1047   -70.9458    MA  0.04  0.05
# 1        1        Acton   Middlesex   42.4850   -71.4333    MA  0.06  0.05
# 2        2     Acushnet     Bristol   41.6806   -70.9083    MA  0.06  0.05
# 3        3        Adams   Berkshire   42.6242   -73.1181    MA  0.04  0.04
# 4        4       Agawam     Hampden   42.0696   -72.6152    MA  0.06  0.04
# ..     ...          ...         ...       ...        ...   ...   ...   ...
# 345    345       Woburn   Middlesex   42.4791   -71.1518    MA  0.06  0.05
# 346    346    Worcester   Worcester   42.2667   -71.8000    MA  0.06  0.05
# 347    347  Worthington   Hampshire   42.3972   -72.9361    MA  0.02  0.05
# 348    348     Wrentham     Norfolk   42.0639   -71.3315    MA  0.07  0.06
# 349    349     Yarmouth  Barnstable   41.7055   -70.2286    MA  0.02  0.06
#
# ...

# %% [markdown]
# ## Crossjoin AA.Patient and AB.Location

# %%
sql = """
SELECT 
P.*,Location.*
FROM AAA.Patient P
inner join AB.Location on P.BirthPlaceCity = Location.City
"""
cur.execute(sql)
cur.fetchall()
# Out:
# [Row(ID=2, BirthPlaceCity='Newton', BirthPlaceCountry='US', BirthPlaceState='Massachusetts', FirstName='Carroll471', Gender='male', IdentifierCode='MR', IdentifierType='Medical Record Number', IdentifierValue='274f5452-2a39-44c4-a7cb-f36de467762e', Key='Patient/2', LastName="O'Hara248", LastUpdated='2024-06-21T15:54:08Z', index=205, City='Newton', County='Middlesex', Latitude=42.3369, Longitude=-71.2097, State='MA', _18=0.05, _19=0.05, _20=0.07, _21=0.08, _22=0.13, _23=0.11, _24=0.12, _25=0.13, _26=0.13, _27=0.08, _28=0.05, F=0.54, M=0.46),
# ...

# %% [markdown]
# ## Display the SQL Query from a dataframe

# %%
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
#     ID BirthPlaceCity BirthPlaceCountry BirthPlaceState    FirstName  Gender  \
# 0    2         Newton                US   Massachusetts   Carroll471    male
# 1    5        Boxford                US   Massachusetts  Gabriele201  female
# 2    7         Rowley                US   Massachusetts   Frankie174    male
# 3  105      Braintree                US   Massachusetts    Margie619  female
#
#   IdentifierCode         IdentifierType                       IdentifierValue  \
# 0             MR  Medical Record Number  274f5452-2a39-44c4-a7cb-f36de467762e
# 1             MR  Medical Record Number  b0223c9b-0019-42b0-99b8-7d689d7f8414
# 2             MR  Medical Record Number  a5b737fb-1f94-4767-802b-1112051f5101
# 3             MR  Medical Record Number  29428a22-5f03-492e-83bb-da34bb2a12c9
#
#            Key  ... 15-19 20-29  30-39 40-49 50-59  60-69  70-79   80+     F  \
# 0    Patient/2  ...  0.08  0.13   0.11  0.12  0.13   0.13   0.08  0.05  0.54
# ...

# %% [markdown]
# ## Display the AA.Observation data after having projected it using FHIR SQL Builder

# %% [markdown]
# ### Alternatively, you can import the misc/T1.json transformation file using FHIR SQL Builder

# %%
pd.read_sql_table('Observation', engine, schema="AAA")
# Out:
#        ID     Code               Key ObservationCodeCodingCode  \
# 0     101       cm   Observation/101                    8302-2
# 1     102  {score}   Observation/102                   72514-3
# 2     103       kg   Observation/103                   29463-7
# 3     104        %   Observation/104                   77606-2
# 4     113     None   Observation/113                   85354-9
# ..    ...      ...               ...                       ...
# 788  2241  {score}  Observation/2241                   72514-3
# 789  2242       kg  Observation/2242                   29463-7
# 790  2243    kg/m2  Observation/2243                   39156-5
# 791  2244     None  Observation/2244                   85354-9
# 792  2245     None  Observation/2245                   72166-2
#
#                           ObservationCodeCodingDisplay  QuantityValue  \
# 0                                          Body Height           76.0
# ...

# %% [markdown]
# ## Crossjoin AA.Patient and AA.Observation

# %%
sql = """
SELECT top 10
P.Key,P.FirstName,P.LastName,O.*
FROM AAA.Patient P
inner join AAA.Observation O on P.Key = O.SubjectReference
"""
cur.execute(sql)
cur.fetchall()
# Out:
# [Row(Key='Patient/5', FirstName='Gabriele201', LastName='Rohan584', ID=101, Code='cm', _5='Observation/101', ObservationCodeCodingCode='8302-2', ObservationCodeCodingDisplay='Body Height', QuantityValue='76.6', SubjectReference='Patient/5', System='http://unitsofmeasure.org', Unit='cm', Value='76.6'),
#  Row(Key='Patient/5', FirstName='Gabriele201', LastName='Rohan584', ID=102, Code='{score}', _5='Observation/102', ObservationCodeCodingCode='72514-3', ObservationCodeCodingDisplay='Pain severity - 0-10 verbal numeric rating [Score] - Reported', QuantityValue='4', SubjectReference='Patient/5', System='http://unitsofmeasure.org', Unit='{score}', Value='4'),
#  Row(Key='Patient/5', FirstName='Gabriele201', LastName='Rohan584', ID=103, Code='kg', _5='Observation/103', ObservationCodeCodingCode='29463-7', ObservationCodeCodingDisplay='Body Weight', QuantityValue='12.3', SubjectReference='Patient/5', System='http://unitsofmeasure.org', Unit='kg', Value='12.3'),
# ...

# %% [markdown]
# ## Display the SQL Query from a dataframe

# %%
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
#          Key    FirstName  LastName   ID     Code              Key  \
# 0  Patient/5  Gabriele201  Rohan584  101       cm  Observation/101
# 1  Patient/5  Gabriele201  Rohan584  102  {score}  Observation/102
# 2  Patient/5  Gabriele201  Rohan584  103       kg  Observation/103
# 3  Patient/5  Gabriele201  Rohan584  104        %  Observation/104
# 4  Patient/5  Gabriele201  Rohan584  113     None  Observation/113
#
#   ObservationCodeCodingCode  \
# 0                    8302-2
# 1                   72514-3
# 2                   29463-7
# 3                   77606-2
# 4                   85354-9
#
#                         ObservationCodeCodingDisplay QuantityValue  \
# 0                                        Body Height          76.6
# 1  Pain severity - 0-10 verbal numeric rating [Sc...             4
# 2                                        Body Weight          12.3
# 3                  Weight-for-length Per age and sex        98.841
# ...

# %% [markdown]
# ## Create new table to store DriverLicense data

# %%
cur.execute("""drop TABLE AB.DriverLicense""")
# Out:
# 0

# %%
# execute a query
cur.execute("""create TABLE AB.DriverLicense (

    Code varchar(255) not null,
    Valid TINYINT not null

)""")
# Out:
# 0

# %% [markdown]
# ## DELETE DriverLicense data

# %%
cur.execute("""delete AB.DriverLicense""")
# Out:
# 0

# %% [markdown]
# ## INSERT DriverLicense data

# %%
cur.execute("""INSERT INTO AB.DriverLicense (Code, Valid) VALUES ('935564323334', 0)""")
cur.execute("""INSERT into AB.DriverLicense (Code, Valid) VALUES ('635564323334', 1)""")
cur.execute("""INSERT into AB.DriverLicense (Code, Valid) VALUES ('187788223334', 1)""")
# Out:
# 1

# %% [markdown]
# ## Display DriverLicense data

# %%
pd.read_sql_table('DriverLicense', engine, schema="AB",columns={"Code","Valid"})
# Out:
#            Code  Valid
# 0  935564323334      0
# 1  635564323334      1
# 2  187788223334      1

# %% [markdown]
# ## Crossjoin AA.Patient and AB.DriverLicense

# %%
sql = """
SELECT 
P.LastName,P.FirstName,P.IdentifierType,DL.*
FROM AAA.Patient P
inner join AB.DriverLicense DL on P.IdentifierValue = DL.Code
"""
cur.execute(sql)
cur.fetchall()
# Out:
# []

# %% [markdown]
# ## Display the SQL Query from a dataframe

# %%
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
# Empty DataFrame
# Columns: [LastName, FirstName, IdentifierType, Code, Valid]
# Index: []
