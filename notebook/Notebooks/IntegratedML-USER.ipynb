# %%
CREATE MODEL PatientReadmission PREDICTING (IsReadmitted) FROM Hospital.PatientDataView
TRAIN MODEL PatientReadmission
VALIDATE MODEL PatientReadmission FROM Hospital.PatientDataViewTesting
SELECT * FROM INFORMATION_SCHEMA.ML_VALIDATION_METRICS
SELECT ID FROM Hospital.NewPatientDataView WHERE PREDICT(PatientReadmission) = 1

# %%
import intersystems_iris as iris
import pandas as pd
from sqlalchemy import create_engine,types

# %%
# create the dbapi connection

host = "host.docker.internal"

port = 2972
namespace = "USER"
user = "_system"
password = "SYS"

conn = iris.connect(
                    hostname=host, 
                    port=port, 
                    namespace=namespace, 
                    username=user, 
                    password=password
                   )

# create a cursor
cur = conn.cursor()

# %%
# create the sqlaclchemy connection
engine = create_engine('iris://_SYSTEM:SYS@host.docker.internal:2972/USER')

# %%
# execute a query
sql = """SELECT top 3
diagnosis
, radiusmean
, texturemean
, perimetermean
, areamean
, smoothnessmean
, compactnessmean
, concavitymean
, concavepointsmean
, symmetrymean
, fractaldimensionmean
, radiusse
, texturese
, perimeterse
, arease
, smoothnessse
, compactnessse
, concavityse
, concavepointsse
, symmetryse
, fractaldimensionse
, radiusworst
, textureworst
, perimeterworst
, areaworst
, smoothnessworst
, compactnessworst
, concavityworst
, concavepointsworst
, symmetryworst
, fractaldimensionworst
FROM dc_data_health.BreastCancer
"""
cur.execute(sql)
cur.fetchall()
# Out:
# [Row(diagnosis='M', radiusmean=Decimal('17.99'), texturemean=Decimal('10.38'), perimetermean=122.8, areamean=1001.0, smoothnessmean=Decimal('0.1184'), compactnessmean=Decimal('0.2776'), concavitymean=Decimal('0.3001'), concavepointsmean=Decimal('0.1471'), symmetrymean=Decimal('0.2419'), fractaldimensionmean=Decimal('0.0787'), radiusse=Decimal('1.095'), texturese=Decimal('0.9053'), perimeterse=Decimal('8.589'), arease=Decimal('153.4'), smoothnessse=Decimal('0.0064'), compactnessse=Decimal('0.0490'), concavityse=Decimal('0.0537'), concavepointsse=Decimal('0.0159'), symmetryse=Decimal('0.0300'), fractaldimensionse=Decimal('0.0062'), radiusworst=Decimal('25.38'), textureworst=Decimal('17.33'), perimeterworst=Decimal('184.6'), areaworst=2019.0, smoothnessworst=Decimal('0.1622'), compactnessworst=Decimal('0.6656'), concavityworst=Decimal('0.7119'), concavepointsworst=Decimal('0.2654'), symmetryworst=Decimal('0.4601'), fractaldimensionworst=Decimal('0.1189')),
#  Row(diagnosis='M', radiusmean=Decimal('20.57'), texturemean=Decimal('17.77'), perimetermean=132.9, areamean=1326.0, smoothnessmean=Decimal('0.0847'), compactnessmean=Decimal('0.0786'), concavitymean=Decimal('0.0869'), concavepointsmean=Decimal('0.0702'), symmetrymean=Decimal('0.1812'), fractaldimensionmean=Decimal('0.0567'), radiusse=Decimal('0.5435'), texturese=Decimal('0.7339'), perimeterse=Decimal('3.398'), arease=Decimal('74.08'), smoothnessse=Decimal('0.0052'), compactnessse=Decimal('0.0131'), concavityse=Decimal('0.0186'), concavepointsse=Decimal('0.0134'), symmetryse=Decimal('0.0139'), fractaldimensionse=Decimal('0.0035'), radiusworst=Decimal('24.99'), textureworst=Decimal('23.41'), perimeterworst=Decimal('158.8'), areaworst=1956.0, smoothnessworst=Decimal('0.1238'), compactnessworst=Decimal('0.1866'), concavityworst=Decimal('0.2416'), concavepointsworst=Decimal('0.186'), symmetryworst=Decimal('0.275'), fractaldimensionworst=Decimal('0.0890')),
#  Row(diagnosis='M', radiusmean=Decimal('19.69'), texturemean=Decimal('21.25'), perimetermean=130.0, areamean=1203.0, smoothnessmean=Decimal('0.1096'), compactnessmean=Decimal('0.1599'), concavitymean=Decimal('0.1974'), concavepointsmean=Decimal('0.1279'), symmetrymean=Decimal('0.2069'), fractaldimensionmean=Decimal('0.0600'), radiusse=Decimal('0.7456'), texturese=Decimal('0.7869'), perimeterse=Decimal('4.585'), arease=Decimal('94.03'), smoothnessse=Decimal('0.0062'), compactnessse=Decimal('0.0401'), concavityse=Decimal('0.0383'), concavepointsse=Decimal('0.0206'), symmetryse=Decimal('0.0225'), fractaldimensionse=Decimal('0.0046'), radiusworst=Decimal('23.57'), textureworst=Decimal('25.53'), perimeterworst=Decimal('152.5'), areaworst=1709.0, smoothnessworst=Decimal('0.1444'), compactnessworst=Decimal('0.4245'), concavityworst=Decimal('0.4504'), concavepointsworst=Decimal('0.243'), symmetryworst=Decimal('0.3613'), fractaldimensionworst=Decimal('0.0876'))]

# %%
pd.read_sql_table('BreastCancer', engine, schema="dc_data_health")
# Out:
#      areamean  arease  areaworst  compactnessmean  compactnessse  \
# 0      1001.0  153.40     2019.0           0.2776         0.0490
# 1      1326.0   74.08     1956.0           0.0786         0.0131
# 2      1203.0   94.03     1709.0           0.1599         0.0401
# 3       386.1   27.23      567.7           0.2839         0.0746
# 4      1297.0   94.44     1575.0           0.1328         0.0246
# ..        ...     ...        ...              ...            ...
# 564    1479.0  158.70     2027.0           0.1159         0.0289
# 565    1261.0   99.04     1731.0           0.1034         0.0242
# 566     858.1   48.55     1124.0           0.1023         0.0373
# 567    1265.0   86.22     1821.0           0.2770         0.0616
# 568     181.0   19.15      268.6           0.0436         0.0047
#
#      compactnessworst  concavepointsmean  concavepointsse  concavepointsworst  \
# 0              0.6656             0.1471           0.0159              0.2654
# 1              0.1866             0.0702           0.0134              0.1860
# 2              0.4245             0.1279           0.0206              0.2430
# 3              0.8663             0.1052           0.0187              0.2575
# 4              0.2050             0.1043           0.0189              0.1625
# ..                ...                ...              ...                 ...
# 564            0.2113             0.1389           0.0245              0.2216
# 565            0.1922             0.0979           0.0168              0.1628
# 566            0.3094             0.0530           0.0156              0.1418
# 567            0.8681             0.1520           0.0166              0.2650
# 568            0.0644             0.0000           0.0000              0.0000
#
#      concavitymean  ...  radiusworst  smoothnessmean smoothnessse  \
# 0           0.3001  ...       25.380          0.1184       0.0064
# 1           0.0869  ...       24.990          0.0847       0.0052
# 2           0.1974  ...       23.570          0.1096       0.0062
# 3           0.2414  ...       14.910          0.1425       0.0091
# 4           0.1980  ...       22.540          0.1003       0.0115
# ..             ...  ...          ...             ...          ...
# 564         0.2439  ...       25.450          0.1110       0.0103
# 565         0.1440  ...       23.690          0.0978       0.0058
# 566         0.0925  ...       18.980          0.0846       0.0059
# 567         0.3514  ...       25.740          0.1178       0.0065
# 568         0.0000  ...        9.456          0.0526       0.0072
#
#      smoothnessworst  symmetrymean  symmetryse  symmetryworst  texturemean  \
# 0             0.1622        0.2419      0.0300         0.4601        10.38
# 1             0.1238        0.1812      0.0139         0.2750        17.77
# 2             0.1444        0.2069      0.0225         0.3613        21.25
# 3             0.2098        0.2597      0.0596         0.6638        20.38
# 4             0.1374        0.1809      0.0176         0.2364        14.34
# ..               ...           ...         ...            ...          ...
# 564           0.1410        0.1726      0.0111         0.2060        22.39
# 565           0.1166        0.1752      0.0190         0.2572        28.25
# 566           0.1139        0.1590      0.0132         0.2218        28.08
# 567           0.1650        0.2397      0.0232         0.4087        29.33
# 568           0.0900        0.1587      0.0268         0.2871        24.54
#
#      texturese  textureworst
# 0       0.9053         17.33
# 1       0.7339         23.41
# 2       0.7869         25.53
# 3       1.1560         26.50
# 4       0.7813         16.67
# ..         ...           ...
# 564     1.2560         26.40
# 565     2.4630         38.25
# 566     1.0750         34.12
# 567     1.5950         39.42
# 568     1.4280         30.37
#
# [569 rows x 31 columns]

# %%
cur.execute("""CREATE MODEL BreastCancer PREDICTING (diagnosis) FROM dc_data_health.BreastCancer""")
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 cur.execute("""CREATE MODEL BreastCancer PREDICTING (diagnosis) FROM dc_data_health.BreastCancer""")
#
# File /opt/conda/lib/python3.11/site-packages/intersystems_iris/dbapi/_DBAPI.py:237, in _BaseCursor.execute(self, operation, params)
#     234 else:
#     235     self._cursor_type = CursorType.DEFAULT
# --> 237 self._execute()
#     238 return self._rowcount
#
# File /opt/conda/lib/python3.11/site-packages/intersystems_iris/dbapi/_DBAPI.py:472, in _BaseCursor._execute(self)
#     470     raise NotImplementedErrorDBAPI(f'StatementType {self._statementType.name} not implemented')
#     471 else:
# --> 472     return exec_func()
#
# File /opt/conda/lib/python3.11/site-packages/intersystems_iris/dbapi/_DBAPI.py:866, in Cursor._execute_update(self)
#     865 def _execute_update(self):
# --> 866     super()._execute_update()
#     868     if self._parameter_sets == 0 and not self._multiple_result_sets:
#     869         self._rowcount = self._in_message.wire._get()
#
# File /opt/conda/lib/python3.11/site-packages/intersystems_iris/dbapi/_DBAPI.py:569, in _BaseCursor._execute_update(self)
#     566         self._prepared_update_execute()
#     567     else:
#     568         # not found in client side cache - send DU message
# --> 569         self._send_direct_update_request()
#     570 else:
#     571     if self._statementType == StatementType.QUERY or self._statementType == StatementType.PREPARED_CALL_QUERY:
#
# File /opt/conda/lib/python3.11/site-packages/intersystems_iris/dbapi/_DBAPI.py:1109, in Cursor._send_direct_update_request(self)
#    1107 self._in_message._read_message_sql(sequence_number, self._statement_id, 0, [100])
#    1108 self._sqlcode = self._in_message.wire.header._get_function_code()
# -> 1109 self._process_sqlcode(self._sqlcode)
#    1111 addToCache = self._get_parameter_info(self._in_message.wire)
#    1113 notDDL = bool(self._statementType != StatementType.DDL_ALTER_DROP
#    1114                   and self._statementType != StatementType.DDL_OTHER)
#
# File /opt/conda/lib/python3.11/site-packages/intersystems_iris/dbapi/_DBAPI.py:677, in Cursor._process_sqlcode(self, sqlcode, message)
#     675 if sqlcode in [0, 100]:
#     676     return
# --> 677 super()._process_sqlcode(sqlcode, self._get_error_info(sqlcode))
#
# File /opt/conda/lib/python3.11/site-packages/intersystems_iris/dbapi/_DBAPI.py:312, in _BaseCursor._process_sqlcode(self, sqlcode, message)
#     310 if abs(sqlcode) in [108, 119, 121, 122]:
#     311     raise IntegrityError(message)
# --> 312 raise DatabaseError(message)
#
# DatabaseError: [SQLCODE: <-180>:<Model name not unique>]
# [Location: <ServerLoop>]
# [%msg: <Model name 'BreastCancer' is not unique>]

# %%
cur.execute("""TRAIN MODEL BreastCancer""")
# Out:
# 1

# %%
#pd.read_sql_table('ML_MODELS', engine, schema="INFORMATION_SCHEMA")
cur.execute("""
SELECT 
MODEL_NAME, DESCRIPTION, PREDICTING_COLUMN_NAME
, PREDICTING_COLUMN_TYPE, WITH_COLUMNS, CREATE_TIMESTAMP
, DEFAULT_TRAINED_MODEL_NAME, DEFAULT_SETTINGS, DEFAULT_TRAINING_QUERY
FROM INFORMATION_SCHEMA.ML_MODELS
""")
cur.fetchall()
# Out:
# [Row(MODEL_NAME='BreastCancer', DESCRIPTION='Model BreastCancer created via SQL by user _SYSTEM on 05/29/2024 14:34:42', PREDICTING_COLUMN_NAME='diagnosis', PREDICTING_COLUMN_TYPE='VARCHAR', WITH_COLUMNS='areamean:DOUBLE, arease:DOUBLE, areaworst:DOUBLE, compactnessmean:DOUBLE, compactnessse:DOUBLE, compactnessworst:DOUBLE, concavepointsmean:DOUBLE, concavepointsse:DOUBLE, concavepointsworst:DOUBLE, concavitymean:DOUBLE, concavityse:DOUBLE, concavityworst:DOUBLE, fractaldimensionmean:DOUBLE, fractaldimensionse:DOUBLE, fractaldimensionworst:DOUBLE, perimetermean:DOUBLE, perimeterse:DOUBLE, perimeterworst:DOUBLE, radiusmean:DOUBLE, radiusse:DOUBLE, radiusworst:DOUBLE, smoothnessmean:DOUBLE, smoothnessse:DOUBLE, smoothnessworst:DOUBLE, symmetrymean:DOUBLE, symmetryse:DOUBLE, symmetryworst:DOUBLE, texturemean:DOUBLE, texturese:DOUBLE, textureworst:DOUBLE', CREATE_TIMESTAMP='2024-05-29 14:34:42.664', DEFAULT_TRAINED_MODEL_NAME='BreastCancer_t2', DEFAULT_SETTINGS=None, DEFAULT_TRAINING_QUERY='SELECT * FROM  dc_data_health . BreastCancer')]

# %%
cur.execute("""
SELECT ID,PREDICT(BreastCancer) predicted, PROBABILITY(BreastCancer), diagnosis 
FROM dc_data_health.BreastCancer
""")
cur.fetchall()
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 cur.execute("""
#       2 SELECT ID,PREDICT(BreastCancer) predicted, PROBABILITY(BreastCancer), diagnosis
#       3 FROM dc_data_health.BreastCancer
#       4 """)
#       5 cur.fetchall()
#
# File /opt/conda/lib/python3.11/site-packages/intersystems_iris/dbapi/_DBAPI.py:237, in _BaseCursor.execute(self, operation, params)
#     234 else:
#     235     self._cursor_type = CursorType.DEFAULT
# --> 237 self._execute()
#     238 return self._rowcount
#
# File /opt/conda/lib/python3.11/site-packages/intersystems_iris/dbapi/_DBAPI.py:472, in _BaseCursor._execute(self)
#     470     raise NotImplementedErrorDBAPI(f'StatementType {self._statementType.name} not implemented')
#     471 else:
# --> 472     return exec_func()
#
# File /opt/conda/lib/python3.11/site-packages/intersystems_iris/dbapi/_DBAPI.py:518, in _BaseCursor._execute_query(self)
#     515         self._prepared_query_execute()
#     516     else:
#     517         # not found in client side cache - send DQ message
# --> 518         self._send_direct_query_request()
#     519 else:
#     520     if (self._statementType != StatementType.QUERY and
#     521         self._statementType != StatementType.PREPARED_CALL_QUERY and
#     522         self._statementType != StatementType.DIRECT_CALL_QUERY):
#
# File /opt/conda/lib/python3.11/site-packages/intersystems_iris/dbapi/_DBAPI.py:1042, in Cursor._send_direct_query_request(self)
#    1040     self._sqlcode = self._in_message.wire.header._get_function_code()
#    1041     if self._sqlcode not in [0, 100]:
# -> 1042         raise DatabaseError(self._get_error_info(self._sqlcode))
#    1044 except IndexError:
#    1045     raise DatabaseError("Server response message terminated prematurely")
#
# DatabaseError: [SQLCODE: <-400>:<Fatal error occurred>]
# [Location: <ServerLoop - Query Fetch>]
# [%msg: <PREDICT execution error: ERROR #2853: Specified positive label value not found in the dataset.>]
