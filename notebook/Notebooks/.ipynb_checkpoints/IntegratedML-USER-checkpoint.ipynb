# %%
CREATE MODEL PatientReadmission PREDICTING (IsReadmitted) FROM Hospital.PatientDataView
TRAIN MODEL PatientReadmission
VALIDATE MODEL PatientReadmission FROM Hospital.PatientDataViewTesting
SELECT * FROM INFORMATION_SCHEMA.ML_VALIDATION_METRICS
SELECT ID FROM Hospital.NewPatientDataView WHERE PREDICT(PatientReadmission) = 1

# %%
import intersystems_iris as iris
import pandas as pd
from sqlalchemy import create_engine,types

# %%
# create the dbapi connection

host = "iris"
port = 1972
namespace = "IRISAPP"
user = "_system"
password = "SYS"

conn = iris.connect(
                    hostname=host, 
                    port=port, 
                    namespace=namespace, 
                    username=user, 
                    password=password
                   )

# create a cursor
cur = conn.cursor()

# %%
# create the sqlaclchemy connection
engine = create_engine('iris://SuperUser:SYS@iris:1972/IRISAPP')

# %%
# execute a query
sql = """SELECT top 3
diagnosis
, radiusmean
, texturemean
, perimetermean
, areamean
, smoothnessmean
, compactnessmean
, concavitymean
, concavepointsmean
, symmetrymean
, fractaldimensionmean
, radiusse
, texturese
, perimeterse
, arease
, smoothnessse
, compactnessse
, concavityse
, concavepointsse
, symmetryse
, fractaldimensionse
, radiusworst
, textureworst
, perimeterworst
, areaworst
, smoothnessworst
, compactnessworst
, concavityworst
, concavepointsworst
, symmetryworst
, fractaldimensionworst
FROM dc_data_health.BreastCancer
"""
cur.execute(sql)
cur.fetchall()
# Out:
# [Row(diagnosis='B', radiusmean=Decimal('15.0400'), texturemean=Decimal('16.7400'), perimetermean=98.73, areamean=689.4, smoothnessmean=Decimal('0.0988'), compactnessmean=Decimal('0.1364'), concavitymean=Decimal('0.0772'), concavepointsmean=Decimal('0.0614'), symmetrymean=Decimal('0.1668'), fractaldimensionmean=Decimal('0.0687'), radiusse=Decimal('0.3720'), texturese=Decimal('0.8423'), perimeterse=Decimal('2.3040'), arease=Decimal('34.8400'), smoothnessse=Decimal('0.0041'), compactnessse=Decimal('0.0182'), concavityse=Decimal('0.0200'), concavepointsse=Decimal('0.0100'), symmetryse=Decimal('0.0106'), fractaldimensionse=Decimal('0.0032'), radiusworst=Decimal('16.7600'), textureworst=Decimal('20.4300'), perimeterworst=Decimal('109.7000'), areaworst=856.9, smoothnessworst=Decimal('0.1135'), compactnessworst=Decimal('0.2176'), concavityworst=Decimal('0.1856'), concavepointsworst=Decimal('0.1018'), symmetryworst=Decimal('0.2177'), fractaldimensionworst=Decimal('0.0855')),
#  Row(diagnosis='M', radiusmean=Decimal('13.8200'), texturemean=Decimal('24.4900'), perimetermean=92.33, areamean=595.9, smoothnessmean=Decimal('0.1162'), compactnessmean=Decimal('0.1681'), concavitymean=Decimal('0.1357'), concavepointsmean=Decimal('0.0676'), symmetrymean=Decimal('0.2275'), fractaldimensionmean=Decimal('0.0724'), radiusse=Decimal('0.4751'), texturese=Decimal('1.5280'), perimeterse=Decimal('2.9740'), arease=Decimal('39.0500'), smoothnessse=Decimal('0.0097'), compactnessse=Decimal('0.0386'), concavityse=Decimal('0.0348'), concavepointsse=Decimal('0.0162'), symmetryse=Decimal('0.0243'), fractaldimensionse=Decimal('0.0070'), radiusworst=Decimal('16.0100'), textureworst=Decimal('32.9400'), perimeterworst=Decimal('106.0000'), areaworst=788.0, smoothnessworst=Decimal('0.1794'), compactnessworst=Decimal('0.3966'), concavityworst=Decimal('0.3381'), concavepointsworst=Decimal('0.1521'), symmetryworst=Decimal('0.3651'), fractaldimensionworst=Decimal('0.1183')),
#  Row(diagnosis='B', radiusmean=Decimal('12.5400'), texturemean=Decimal('16.3200'), perimetermean=81.25, areamean=476.3, smoothnessmean=Decimal('0.1158'), compactnessmean=Decimal('0.1085'), concavitymean=Decimal('0.0593'), concavepointsmean=Decimal('0.0328'), symmetrymean=Decimal('0.1943'), fractaldimensionmean=Decimal('0.0661'), radiusse=Decimal('0.2577'), texturese=Decimal('1.0950'), perimeterse=Decimal('1.5660'), arease=Decimal('18.4900'), smoothnessse=Decimal('0.0097'), compactnessse=Decimal('0.0157'), concavityse=Decimal('0.0258'), concavepointsse=Decimal('0.0116'), symmetryse=Decimal('0.0280'), fractaldimensionse=Decimal('0.0025'), radiusworst=Decimal('13.5700'), textureworst=Decimal('21.4000'), perimeterworst=Decimal('86.6700'), areaworst=552.0, smoothnessworst=Decimal('0.1580'), compactnessworst=Decimal('0.1751'), concavityworst=Decimal('0.1889'), concavepointsworst=Decimal('0.0841'), symmetryworst=Decimal('0.3155'), fractaldimensionworst=Decimal('0.0754'))]

# %%
pd.read_sql_table('BreastCancer', engine, schema="dc_data_health")
# Out:
#     diagnosis  radiusmean  texturemean  perimetermean  areamean  \
# 0           B      15.040        16.74          98.73     689.4
# 1           M      13.820        24.49          92.33     595.9
# 2           B      12.540        16.32          81.25     476.3
# 3           M      23.090        19.83         152.10    1682.0
# 4           B       9.268        12.87          61.49     248.7
# ..        ...         ...          ...            ...       ...
# 564         B      14.870        20.21          96.12     680.9
# 565         B      12.650        18.17          82.69     485.6
# 566         B      12.470        17.31          80.45     480.1
# 567         M      18.490        17.52         121.30    1068.0
# 568         M      20.590        21.24         137.80    1320.0
#
#      smoothnessmean  compactnessmean  concavitymean  concavepointsmean  \
# 0            0.0988           0.1364         0.0772             0.0614
# 1            0.1162           0.1681         0.1357             0.0676
# 2            0.1158           0.1085         0.0593             0.0328
# 3            0.0934           0.1275         0.1676             0.1003
# 4            0.1634           0.2239         0.0973             0.0525
# ..              ...              ...            ...                ...
# 564          0.0959           0.0835         0.0682             0.0495
# 565          0.1076           0.1334         0.0802             0.0507
# 566          0.0893           0.0763         0.0361             0.0237
# 567          0.1012           0.1317         0.1491             0.0918
# 568          0.1085           0.1644         0.2188             0.1121
#
#      symmetrymean  ...  radiusworst  textureworst  perimeterworst  areaworst  \
# 0          0.1668  ...        16.76         20.43          109.70      856.9
# 1          0.2275  ...        16.01         32.94          106.00      788.0
# 2          0.1943  ...        13.57         21.40           86.67      552.0
# 3          0.1505  ...        30.79         23.87          211.50     2782.0
# 4          0.2378  ...        10.28         16.38           69.05      300.2
# ..            ...  ...          ...           ...             ...        ...
# 564        0.1487  ...        16.01         28.48          103.90      783.6
# 565        0.1641  ...        14.38         22.15           95.29      633.7
# 566        0.1526  ...        14.06         24.34           92.82      607.3
# 567        0.1832  ...        22.75         22.88          146.40     1600.0
# 568        0.1848  ...        23.86         30.76          163.20     1760.0
#
#      smoothnessworst  compactnessworst  concavityworst  concavepointsworst  \
# 0             0.1135            0.2176          0.1856              0.1018
# 1             0.1794            0.3966          0.3381              0.1521
# 2             0.1580            0.1751          0.1889              0.0841
# 3             0.1199            0.3625          0.3794              0.2264
# 4             0.1902            0.3441          0.2099              0.1025
# ..               ...               ...             ...                 ...
# 564           0.1216            0.1388          0.1700              0.1017
# 565           0.1533            0.3842          0.3582              0.1407
# 566           0.1276            0.2506          0.2028              0.1053
# 567           0.1412            0.3089          0.3533              0.1663
# 568           0.1464            0.3597          0.5179              0.2113
#
#      symmetryworst  fractaldimensionworst
# 0           0.2177                 0.0855
# 1           0.3651                 0.1183
# 2           0.3155                 0.0754
# 3           0.2908                 0.0728
# 4           0.3038                 0.1252
# ..             ...                    ...
# 564         0.2369                 0.0660
# 565         0.3230                 0.1033
# 566         0.3035                 0.0766
# 567         0.2510                 0.0945
# 568         0.2480                 0.0900
#
# [569 rows x 31 columns]
